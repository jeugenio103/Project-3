# %%
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
# Import libraries
import glob
import pandas as pd

# Get CSV files list from a folder
path = './DataSets'
csv_files = glob.glob(path + "/*.csv")

# Read each CSV file into DataFrame
# This creates a list of dataframes
ind_dfs = (pd.read_csv(file) for file in csv_files)

# Concatenate all DataFrames
aio_df   = pd.concat(ind_dfs, ignore_index=True)

# %%
aio_df
# Out:
#      Unnamed: 0                                        song name  \
# 0             0                             world.execute (me) ;
# 1             1  Rightfully (TV Animation Goblin Slayer opening)
# 2             2                          In Hell We Live, Lament
# 3             3                                  Mortal With You
# 4             4                                 String Theocracy
# ..          ...                                              ...
# 465          15                                   How We Used To
# 466          16                                 Little Lifetimes
# 467          17                     Appreciate - English Version
# 468          18                                      Daydreaming
# 469          19                                         Paranoia
#
#                                                album            artist  \
# 0                                       Miracle Milk              Mili
# 1    Rightfully (TV Animation Goblin Slayer opening)              Mili
# 2                            In Hell We Live, Lament              Mili
# 3                                    Mortal With You              Mili
# 4       To Kill a Living Book -for Library Of Ruina-              Mili
# ..                                               ...               ...
# 465                                   How We Used To  Stephanie Poetri
# 466                                 oh to be in love  Stephanie Poetri
# 467                     Appreciate (English Version)  Stephanie Poetri
# 468                                            AM:PM  Stephanie Poetri
# 469                                            AM:PM  Stephanie Poetri
#
#                  featured release_date  length(ms)  popularity  acousticness  \
# 0                ['Mili']   2016-10-12      211912          52       0.00453
# 1                ['Mili']   2018-11-18      213333          54       0.00423
# 2       ['Mili', 'KIHOW']   2021-12-21      223807          48       0.22800
# 3                ['Mili']   2022-07-06      235773          50       0.40200
# 4                ['Mili']   2021-10-29      174170          49       0.17400
# ..                    ...          ...         ...         ...           ...
# 465  ['Stephanie Poetri']   2021-01-14      169655          29       0.74100
# 466  ['Stephanie Poetri']   2022-03-18      158769          28       0.75900
# 467  ['Stephanie Poetri']   2019-04-19      235627          30       0.17400
# 468  ['Stephanie Poetri']   2021-03-12      170181          23       0.82300
# 469  ['Stephanie Poetri']   2021-03-12      176080          24       0.34800
#
#      danceability  energy  liveness    tempo  valence
# 0           0.522   0.817    0.3930  129.971    0.548
# 1           0.390   0.724    0.1020  181.910    0.301
# 2           0.450   0.558    0.2880  124.818    0.146
# 3           0.381   0.525    0.0946  183.635    0.232
# 4           0.655   0.780    0.3320  116.027    0.659
# ..            ...     ...       ...      ...      ...
# 465         0.721   0.490    0.1080   75.005    0.502
# 466         0.352   0.350    0.1130   91.525    0.376
# 467         0.664   0.831    0.1230  119.991    0.388
# 468         0.758   0.584    0.1800  109.949    0.631
# 469         0.614   0.420    0.2120  150.054    0.336
#
# [470 rows x 14 columns]

# %%
aio_df.drop(['Unnamed: 0'], axis = 1, inplace = True) 
aio_df

# %%
aio_df.dtypes
# Out:
# song name        object
# album            object
# artist           object
# featured         object
# release_date     object
# length(ms)        int64
# popularity        int64
# acousticness    float64
# danceability    float64
# energy          float64
# liveness        float64
# tempo           float64
# valence         float64
# dtype: object

# %%
type(aio_df['featured'][0])
# Out:
# str

# %%
aio_df['featured'] = aio_df['featured'].apply(lambda x: re.sub("['[\]]", "", x))

# %%
aio_df['featured'] = aio_df['featured'].apply(lambda x: x.split(sep=', '))

# %%
type(aio_df['featured'][0])
# Out:
# list

# %%
aio_df['featured'][0]
# Out:
# ['Mili']

# %%
# aio_df.to_csv('./DataSets/final.csv', sep = ',')

# %%
new_88df = aio_df[aio_df['featured'].apply(lambda x: len(x) == 1)]
new_88df = new_88df.reset_index(drop=True)
new_88df
# Out:
#                                            song name  \
# 0                               world.execute (me) ;
# 1    Rightfully (TV Animation Goblin Slayer opening)
# 2                                    Mortal With You
# 3                                   String Theocracy
# 4                                      Paper Bouquet
# ..                                               ...
# 250                                   How We Used To
# 251                                 Little Lifetimes
# 252                     Appreciate - English Version
# 253                                      Daydreaming
# 254                                         Paranoia
#
#                                                album            artist  \
# 0                                       Miracle Milk              Mili
# 1    Rightfully (TV Animation Goblin Slayer opening)              Mili
# 2                                    Mortal With You              Mili
# 3       To Kill a Living Book -for Library Of Ruina-              Mili
# 4                                      Paper Bouquet              Mili
# ..                                               ...               ...
# 250                                   How We Used To  Stephanie Poetri
# 251                                 oh to be in love  Stephanie Poetri
# 252                     Appreciate (English Version)  Stephanie Poetri
# 253                                            AM:PM  Stephanie Poetri
# 254                                            AM:PM  Stephanie Poetri
#
#                featured release_date  length(ms)  popularity  acousticness  \
# 0                [Mili]   2016-10-12      211912          52       0.00453
# 1                [Mili]   2018-11-18      213333          54       0.00423
# 2                [Mili]   2022-07-06      235773          50       0.40200
# 3                [Mili]   2021-10-29      174170          49       0.17400
# 4                [Mili]   2022-04-02      208559          46       0.01140
# ..                  ...          ...         ...         ...           ...
# 250  [Stephanie Poetri]   2021-01-14      169655          29       0.74100
# 251  [Stephanie Poetri]   2022-03-18      158769          28       0.75900
# 252  [Stephanie Poetri]   2019-04-19      235627          30       0.17400
# 253  [Stephanie Poetri]   2021-03-12      170181          23       0.82300
# 254  [Stephanie Poetri]   2021-03-12      176080          24       0.34800
#
#      danceability  energy  liveness    tempo  valence
# 0           0.522   0.817    0.3930  129.971    0.548
# 1           0.390   0.724    0.1020  181.910    0.301
# 2           0.381   0.525    0.0946  183.635    0.232
# 3           0.655   0.780    0.3320  116.027    0.659
# 4           0.563   0.867    0.2100  106.034    0.665
# ..            ...     ...       ...      ...      ...
# 250         0.721   0.490    0.1080   75.005    0.502
# 251         0.352   0.350    0.1130   91.525    0.376
# 252         0.664   0.831    0.1230  119.991    0.388
# 253         0.758   0.584    0.1800  109.949    0.631
# 254         0.614   0.420    0.2120  150.054    0.336
#
# [255 rows x 13 columns]

# %%
overall_stats = new_88df.groupby('artist').agg({'acousticness': ['mean'],
                                             'energy': ['mean'],
                                             'liveness': ['mean'],
                                             'valence': ['mean'],
                                              })
overall_stats
# Out:
#                  acousticness    energy  liveness   valence
#                          mean      mean      mean      mean
# artist
# BIBI                 0.484465  0.518654  0.145904  0.405885
# CHUNG HA             0.385087  0.704509  0.179553  0.509327
# Guapdad 4000         0.151419  0.575100  0.100830  0.554500
# Higher Brothers      0.126046  0.758400  0.182890  0.593100
# Jackson Wang         0.180052  0.640000  0.159087  0.544700
# Joji                 0.611817  0.460167  0.209456  0.224972
# Mili                 0.431547  0.547184  0.139845  0.434687
# NIKI                 0.431946  0.479538  0.110904  0.363473
# Rich Brian           0.325285  0.589654  0.197962  0.439162
# Stephanie Poetri     0.591125  0.484375  0.145944  0.491750

# %%
spec_stats = new_88df.groupby('artist').agg({'popularity': ['mean'],
                                             'tempo': ['mean']
                                              })
spec_stats
# Out:
#                  popularity       tempo
#                        mean        mean
# artist
# BIBI              49.653846  118.138846
# CHUNG HA          35.254545  121.579382
# Guapdad 4000      37.400000  127.036600
# Higher Brothers   31.300000  139.008200
# Jackson Wang      49.066667  129.973233
# Joji              72.277778  124.129944
# Mili              38.026316  121.379500
# NIKI              57.115385  120.678154
# Rich Brian        46.423077  123.217269
# Stephanie Poetri  34.437500  102.252625

# %%
overall_stats.plot(
        kind='bar',
        stacked=False,
        figsize=(10,10),
        rot=45,
        title='Average Feature Measure by 88Rising Artist')

legend = plt.legend(['accoucticeness (confidence)','energy (intensity)',
                        'liveness (live audience)', 'valence(positivity)'],title="Measure Values",
                    loc=1, fontsize='small', fancybox=True)

# %%
spec_stats.plot(
        kind='bar',
        stacked=False,
        figsize=(10,10),
        rot=45,
        title='Average Popularity/Tempo Measure by 88Rising Artist')

spec_legend = plt.legend(['popularity (rating)','tempo (speed)'],title="Measure Values",
                    loc=1, fontsize='small', fancybox=True)

# %%
total_tracks = new_88df['artist'].value_counts().to_frame()
total_tracks.reset_index(inplace=True)
total_tracks = total_tracks.rename(columns={'index':'artist', 'artist': 'total_tracks'})
total_tracks
# Out:
#              artist  total_tracks
# 0          CHUNG HA            55
# 1              Mili            38
# 2      Jackson Wang            30
# 3        Rich Brian            26
# 4              BIBI            26
# 5              NIKI            26
# 6              Joji            18
# 7  Stephanie Poetri            16
# 8   Higher Brothers            10
# 9      Guapdad 4000            10

# %%
import seaborn
  
seaborn.PairGrid(new_88df).map_lower(plt.scatter)

# %%
# file1 = './DataSets/This_Is_BIBI.csv'
# file2 = './DataSets/This_Is_CHUNG_HA.csv'
# file3 = './DataSets/This_Is_Guapdad_4000.csv'
# file4 = './DataSets/This_Is_Higher_Brothers.csv'
# file5 = './DataSets/This_Is_Jackson_Wang.csv'
# file6 = './DataSets/This_Is_Joji.csv'
# file7 = './DataSets/This_Is_Mili.csv'
# file8 = './DataSets/This_Is_NIKI.csv'
# file9 = './DataSets/This_Is_Rich_Brian.csv'
# file10 = './DataSets/This_Is_Stephanie_Poetri.csv'

# %%
# df1 = pd.read_csv(file1, encoding="ISO-8859-1")
# df2 = pd.read_csv(file2, encoding="ISO-8859-1")
# df3 = pd.read_csv(file3, encoding="ISO-8859-1")
# df4 = pd.read_csv(file4, encoding="ISO-8859-1")
# df5 = pd.read_csv(file5, encoding="ISO-8859-1")
# df6 = pd.read_csv(file6, encoding="ISO-8859-1")
# df7 = pd.read_csv(file7, encoding="ISO-8859-1")
# df8 = pd.read_csv(file8, encoding="ISO-8859-1")
# df9 = pd.read_csv(file9, encoding="ISO-8859-1")
# df10 = pd.read_csv(file10, encoding="ISO-8859-1")

# %%
# df1 = df1[df1['artist'] == 'BIBI'] 
# df2 = df2[df2['artist'] == 'CHUNG HA'] 
# df3 = df3[df3['artist'] == 'Jackson Wang'] 
# df4 = df4[df4['artist'] == 'Joji'] 
# df5 = df5[df5['artist'] == 'Mili'] 
# df6 = df6[df6['artist'] == 'NIKI'] 
# df7 = df7[df7['artist'] == 'Rich Brian'] 
# df8 = df8[df8['artist'] == 'Stephani Poetri'] 
# df9 = df9[df9['artist'] == 'Guapdad 4000'] 
# df10 = df10[df10['artist'] == 'Higher Brothers']

# %%
# Rising88DF = pd.concat([df1,df2, df3,df4,df5,df5,df6,df7,df8,df9,df10])

# %%
# new_df = Rising88DF.rename(
#     columns={"Unnamed: 0": "ID"})

# %%
# new_df

# %%
# #reset index
# new_df.reset_index(drop=True, inplace=True)

# %%
# new_df.drop_duplicates("song name", inplace=True)

# %%
# new_df

# %%
# new_df.set_index(['ID'], inplace=True)

# %%
# new_df

# %%
# new_df.to_csv('./DataSets/final88data.csv', sep = ',')

# %%
#Filter Collab below
