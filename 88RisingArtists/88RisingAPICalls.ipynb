# %%
#Import Dependencies 
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import base64
from config import client_id, client_secret
import pandas as pd
from urllib.parse import urlencode
from pprint import pprint

# %%
#Sign in thru Spotidy credtentials from dashboard 
client_credentials_manager = SpotifyClientCredentials(client_id,client_secret)

#Authorize credentials with token 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/og/Desktop/Data - Challenges/Project-3/88RisingArtists/88RisingAPICalls.ipynb Cell 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/og/Desktop/Data%20-%20Challenges/Project-3/88RisingArtists/88RisingAPICalls.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> #Sign in thru Spotidy credtentials from dashboard
# ----> <a href='vscode-notebook-cell:/Users/og/Desktop/Data%20-%20Challenges/Project-3/88RisingArtists/88RisingAPICalls.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> client_credentials_manager = SpotifyClientCredentials(client_id,client_secret)
#       <a href='vscode-notebook-cell:/Users/og/Desktop/Data%20-%20Challenges/Project-3/88RisingArtists/88RisingAPICalls.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> #Authorize credentials with token
#       <a href='vscode-notebook-cell:/Users/og/Desktop/Data%20-%20Challenges/Project-3/88RisingArtists/88RisingAPICalls.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
#
# NameError: name 'SpotifyClientCredentials' is not defined

# %%
#Add artist name after "is"
playlist_name = 'This is '

# %%
#Query for playlist ID 
#Playlist should be start with "This is ... " ** cap sensitive **
results= sp.search(playlist_name, type='playlist',limit='03')
pprint(results)
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=This+Is+Highest+Brothers&type=playlist&offset=0&limit=3',
#                'items': [{'collaborative': False,
#                           'description': 'This is Higher Brothers. The '
#                                          'essential tracks, all in one '
#                                          'playlist.',
#                           'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DZ06evO00kpwd'},
#                           'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO00kpwd',
#                           'id': '37i9dQZF1DZ06evO00kpwd',
#                           'images': [{'height': None,
#                                       'url': 'https://thisis-images.scdn.co/37i9dQZF1DZ06evO00kpwd-large.jpg',
#                                       'width': None}],
#                           'name': 'This Is Higher Brothers',
#                           'owner': {'display_name': 'Spotify',
#                                     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#                                     'href': 'https://api.spotify.com/v1/users/spotify',
#                                     'id': 'spotify',
#                                     'type': 'user',
#                                     'uri': 'spotify:user:spotify'},
#                           'primary_color': None,
#                           'public': None,
#                           'snapshot_id': 'Mjc3OTE0NjUsMDAwMDAwMDBmMTA5M2QxZDQ1ZTRlMmZlY2IyM2FjMGQzMmFkMjRjMQ==',
#                           'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO00kpwd/tracks',
#                                      'total': 50},
#                           'type': 'playlist',
#                           'uri': 'spotify:playlist:37i9dQZF1DZ06evO00kpwd'},
#                          {'collaborative': False,
#                           'description': 'This is The Highwaymen. The '
#                                          'essential tracks, all in one '
#                                          'playlist.',
#                           'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DZ06evO3FRpH0'},
#                           'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO3FRpH0',
#                           'id': '37i9dQZF1DZ06evO3FRpH0',
#                           'images': [{'height': None,
#                                       'url': 'https://thisis-images.scdn.co/37i9dQZF1DZ06evO3FRpH0-default.jpg',
#                                       'width': None}],
#                           'name': 'This Is The Highwaymen',
#                           'owner': {'display_name': 'Spotify',
#                                     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#                                     'href': 'https://api.spotify.com/v1/users/spotify',
#                                     'id': 'spotify',
#                                     'type': 'user',
#                                     'uri': 'spotify:user:spotify'},
#                           'primary_color': None,
#                           'public': None,
#                           'snapshot_id': 'Mjc3OTE0NjUsMDAwMDAwMDBhODhhZGU5NWI5NjQyNDA3NjNlZTA3MmM0NmZkMWQyOA==',
#                           'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO3FRpH0/tracks',
#                                      'total': 28},
#                           'type': 'playlist',
#                           'uri': 'spotify:playlist:37i9dQZF1DZ06evO3FRpH0'},
#                          {'collaborative': False,
#                           'description': 'This is The High Kings. The '
#                                          'essential tracks, all in one '
#                                          'playlist.',
#                           'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DZ06evO3RbWT0'},
#                           'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO3RbWT0',
#                           'id': '37i9dQZF1DZ06evO3RbWT0',
#                           'images': [{'height': None,
#                                       'url': 'https://thisis-images.scdn.co/37i9dQZF1DZ06evO3RbWT0-large.jpg',
#                                       'width': None}],
#                           'name': 'This Is The High Kings',
#                           'owner': {'display_name': 'Spotify',
#                                     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#                                     'href': 'https://api.spotify.com/v1/users/spotify',
#                                     'id': 'spotify',
#                                     'type': 'user',
#                                     'uri': 'spotify:user:spotify'},
#                           'primary_color': None,
#                           'public': None,
#                           'snapshot_id': 'Mjc3OTE0NjUsMDAwMDAwMDBiNzk3NWFiMGRhMjI4MmNhMjE2Mzc5M2EyNjc1NTRjNA==',
#                           'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO3RbWT0/tracks',
#                                      'total': 43},
#                           'type': 'playlist',
#                           'uri': 'spotify:playlist:37i9dQZF1DZ06evO3RbWT0'}],
#                'limit': 3,
#                'next': 'https://api.spotify.com/v1/search?query=This+Is+Highest+Brothers&type=playlist&offset=3&limit=3',
#                'offset': 0,
#                'previous': None,
#                'total': 30}}

# %%
#Default spotify profile id 
Spotify_profile_id = 'cef03df234f441af'

# %%
#Extract playlist id and name for top artist 
name = results['playlists']['items'][0]['name'].replace(" ", "_")
playlist_id = results['playlists']['items'][0]['id']
print(name)
print(playlist_id)
# Out:
# This_Is_Higher_Brothers
# 37i9dQZF1DZ06evO00kpwd

# %%
#Create function to get indiidual track id 
def getTrackID(user,playlist_id):
    #Create a empty list to store ID's 
    id = []
    play_list = sp.user_playlist(user,playlist_id)

    #Loop thru ID's
    for item in play_list['tracks']['items']:
        track = item['track']
        id.append(track['id'])
    return id

# %%
#Create function to get ID features 
def getTrackFeatures(id):

    #Query spotify track and feature attribute
    info = sp.track(id)
    features = sp.audio_features(id)
    artists_dict = []
    #Append info and features for specific track ID's
    name = info['name']
    album = info['album']['name']
    artist = info['album']['artists'][0]['name']
    for i in range(3):
        if i == 3: break
        try:
            artists_dict.append(info['artists'][i]['name'])
        except:(IndexError)
        i = i + 1

    release_date = info['album']['release_date']
    length = info['duration_ms']
    popularity = info['popularity']


    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    livenss = features[0]['liveness']
    tempo = features[0]['tempo']
    valence = features[0]['valence']

    track = [name,album,artist,artists_dict,release_date,length,popularity,acousticness,danceability,energy,livenss,tempo,valence]

    return track

# %%
# ('spotify_id','playlist_id')
id = getTrackID(Spotify_profile_id,playlist_id)

# %%
#Create dataframe and loop thru each track ID features to PD
playlist = []
for i in range(len(id)):
    song = getTrackFeatures(id[i])
    playlist.append(song)
    
df = pd.DataFrame(playlist,columns = ['song name','album','artist','featured','release_date','length(ms)','popularity','acousticness','danceability','energy','liveness','tempo','valence'])
    
df.to_csv(f"./Data Sets/{name}.csv", sep = ',')

# %%
#Display dataframe 
df.head(50)
# Out:
#                                             song name  \
# 0        Tequila Sunrise (feat. AUGUST 08 & GoldLink)
# 1                                       R&B All Night
# 2   Midsummer Madness 20 (feat. Joji, Rich Brian, ...
# 3                                        Lover Boy 88
# 4                       Crush On You (feat. step.jad)
# 5                                         Mr. Bentley
# 6                                          2 The Face
# 7                      Lucy Liu (feat. Bohan Phoenix)
# 8                          Amsterdam (feat. KnowKnow)
# 9                     Face Power (feat. Jackson Wang)
# 10                                              Storm
# 11                               No More (feat. NIKI)
# 12                                    Prince Charming
# 13                                I Love You 3000 III
# 14                                      Made In China
# 15                                    Flexing So Hard
# 16                                             Empire
# 17                                     Love Song 4 Me
# 18                                                暴风雨
# 19  One Punch Man (feat. Ski Mask The Slump God & ...
# 20                                           Flo Rida
# 21                               Nomadic (feat. Joji)
# 22  Midsummer Madness (feat. Joji, Rich Brian, Hig...
# 23                                         Red Rubies
# 24                                             WeChat
# 25                                     Gong Xi Fa Cai
# 26                     Private Party (feat. KnowKnow)
# 27                                          Let It Go
# 28                                  Role Playing Game
# 29                  Friends & Foes (feat. Snoop Dogg)
# 30                                          Isabellae
# 31                                           16 Hours
# 32                                       Disrespectin
# 33                                                 Go
# 34                                       Hold Me Down
# 35                                            Diamond
# 36                                      Swimming Pool
# 37                                                711
# 38                                      Nothing Wrong
# 39                                            Chengdu
# 40                     Nothing Wrong (feat. Goldlink)
# 41                                       Young Master
# 42  Talk Less and Feel More (feat. AUGUST 08, Barn...
# 43                                            NO HOOK
# 44                      Lose Control (feat. KnowKnow)
# 45                                           Wudidong
# 46                                          5:30 A.M.
# 47                                       Room Service
# 48                    King of the Jungle (feat. Melo)
# 49                                               Yahh
#
#                                                 album           artist  \
# 0                               Head In The Clouds II         88rising
# 1                                  Mr. Enjoy Da Money         KnowKnow
# 2   Midsummer Madness 20 (feat. Joji, Rich Brian, ...         88rising
# 3                                  Head In The Clouds         88rising
# 4                                     Prince Charming          Masiwei
# 5                                  Mr. Enjoy Da Money         KnowKnow
# 6                               Head In The Clouds II         88rising
# 7                                          PSYLIFE.25            Psy.P
# 8                                     Prince Charming          Masiwei
# 9                                  Mr. Enjoy Da Money         KnowKnow
# 10                                        Type-3 - EP  Higher Brothers
# 11                                         Five Stars  Higher Brothers
# 12                                    Prince Charming          Masiwei
# 13                                 Mr. Enjoy Da Money         KnowKnow
# 14                                      Made In China  Higher Brothers
# 15                                         Five Stars  Higher Brothers
# 16                                             Empire  Higher Brothers
# 17                                 Mr. Enjoy Da Money         KnowKnow
# 18                                             Type-3  Higher Brothers
# 19                                         Five Stars  Higher Brothers
# 20                                           Flo Rida  Higher Brothers
# 21                               Nomadic (feat. Joji)  Higher Brothers
# 22  Midsummer Madness (feat. Joji, Rich Brian, Hig...         88rising
# 23                                 Head In The Clouds         88rising
# 24                                          Black Cab  Higher Brothers
# 25                                         Five Stars  Higher Brothers
# 26                                    Prince Charming          Masiwei
# 27                                 Head In The Clouds         88rising
# 28                                 Mr. Enjoy Da Money         KnowKnow
# 29                  Friends & Foes (feat. Snoop Dogg)  Higher Brothers
# 30                                          Black Cab  Higher Brothers
# 31                                         Five Stars  Higher Brothers
# 32                                 Head In The Clouds         88rising
# 33                                    Prince Charming          Masiwei
# 34                              Head In The Clouds II         88rising
# 35                                         Five Stars  Higher Brothers
# 36                                 Head In The Clouds         88rising
# 37                                          Black Cab  Higher Brothers
# 38                                        Type-3 - EP  Higher Brothers
# 39                                    Prince Charming          Masiwei
# 40                                 Head In The Clouds         88rising
# 41                                          Black Cab  Higher Brothers
# 42                                         Old Master             Melo
# 43                                 JALA (@1580518553)    Bohan Phoenix
# 44                                         PSYLIFE.25            Psy.P
# 45                                          Black Cab  Higher Brothers
# 46                                        Type-3 - EP  Higher Brothers
# 47                           Journey to the West - EP  Higher Brothers
# 48                                         PSYLIFE.25            Psy.P
# 49                                          Black Cab  Higher Brothers
#
#                                              featured release_date  \
# 0           [88rising, Jackson Wang, Higher Brothers]   2019-10-11
# 1                         [KnowKnow, Higher Brothers]   2019-12-12
# 2                  [88rising, Danny Ocean, AUGUST 08]   2020-08-14
# 3          [88rising, Phum Viphurit, Higher Brothers]   2018-07-20
# 4                [Masiwei, Higher Brothers, step.jad]   2020-02-28
# 5                         [KnowKnow, Higher Brothers]   2019-12-12
# 6             [88rising, Rich Brian, Higher Brothers]   2019-10-11
# 7             [Psy.P, Higher Brothers, Bohan Phoenix]   2020-05-27
# 8                [Masiwei, Higher Brothers, KnowKnow]   2020-02-28
# 9           [KnowKnow, Higher Brothers, Jackson Wang]   2019-12-12
# 10                        [Higher Brothers, Harikiri]   2018-02-27
# 11                            [Higher Brothers, NIKI]   2019-02-22
# 12                         [Masiwei, Higher Brothers]   2020-02-28
# 13                        [KnowKnow, Higher Brothers]   2019-12-12
# 14                        [Higher Brothers, DJ Snake]   2018-04-13
# 15                                  [Higher Brothers]   2019-02-22
# 16                                  [Higher Brothers]   2020-11-09
# 17                        [KnowKnow, Higher Brothers]   2019-12-12
# 18                        [Higher Brothers, Harikiri]   2018-02-27
# 19  [Higher Brothers, Denzel Curry, Ski Mask The S...   2019-02-22
# 20          [Higher Brothers, Ski Mask The Slump God]   2017-11-16
# 21                            [Higher Brothers, Joji]   2017-07-13
# 22             [88rising, AUGUST 08, Higher Brothers]   2018-09-25
# 23                  [88rising, Rich Brian, Yung Bans]   2018-07-20
# 24                       [Higher Brothers, Keith Ape]   2017-05-31
# 25                                  [Higher Brothers]   2019-02-22
# 26               [Masiwei, Higher Brothers, KnowKnow]   2020-02-28
# 27            [88rising, Higher Brothers, BlocBoy JB]   2018-07-20
# 28                        [KnowKnow, Higher Brothers]   2019-12-12
# 29                      [Higher Brothers, Snoop Dogg]   2019-08-05
# 30                                  [Higher Brothers]   2017-05-31
# 31                                  [Higher Brothers]   2019-02-22
# 32            [88rising, Rich Brian, Higher Brothers]   2018-07-20
# 33                         [Masiwei, Higher Brothers]   2020-02-28
# 34                        [88rising, Higher Brothers]   2019-10-11
# 35                                  [Higher Brothers]   2019-02-22
# 36             [88rising, Higher Brothers, 03 Greedo]   2018-07-20
# 37                                  [Higher Brothers]   2017-05-31
# 38                        [Higher Brothers, Harikiri]   2018-02-27
# 39                         [Masiwei, Higher Brothers]   2020-02-28
# 40              [88rising, Higher Brothers, Harikiri]   2018-07-20
# 41                                  [Higher Brothers]   2017-05-31
# 42                 [Melo, Higher Brothers, AUGUST 08]   2020-04-20
# 43                   [Bohan Phoenix, Higher Brothers]   2017-01-27
# 44                 [Psy.P, Higher Brothers, KnowKnow]   2020-05-26
# 45                                  [Higher Brothers]   2017-05-31
# 46                        [Higher Brothers, Harikiri]   2018-02-27
# 47                                  [Higher Brothers]   2018-01-17
# 48                     [Psy.P, Higher Brothers, Melo]   2020-05-26
# 49                           [Higher Brothers, J.Mag]   2017-05-31
#
#     length(ms)  popularity  acousticness  danceability  energy  liveness  \
# 0       243332          52       0.03130         0.800   0.545    0.0929
# 1       233846          49       0.00638         0.761   0.545    0.0456
# 2       246947          50       0.49800         0.726   0.789    0.0907
# 3       233033          49       0.34900         0.734   0.699    0.2610
# 4       229064          46       0.64200         0.832   0.662    0.1070
# 5       159183          45       0.39000         0.891   0.746    0.0946
# 6       151531          42       0.16800         0.649   0.684    0.1410
# 7       206400          41       0.00459         0.829   0.643    0.2570
# 8       187058          39       0.24400         0.803   0.672    0.1070
# 9       178983          38       0.30500         0.793   0.737    0.0945
# 10      158785          37       0.12200         0.759   0.627    0.4060
# 11      229859          38       0.43600         0.750   0.651    0.0776
# 12      208235          38       0.13700         0.889   0.840    0.1280
# 13      210666          36       0.85900         0.467   0.482    0.3330
# 14      171733          43       0.00397         0.790   0.779    0.1590
# 15      175384          37       0.00256         0.698   0.741    0.3260
# 16      207761          36       0.21400         0.797   0.767    0.0713
# 17      168000          32       0.08790         0.808   0.645    0.1030
# 18      158785          28       0.12200         0.759   0.627    0.4060
# 19      200651          40       0.08550         0.906   0.726    0.1270
# 20      208048          39       0.10900         0.900   0.649    0.0825
# 21      244800          38       0.05010         0.840   0.536    0.7300
# 22      238888          33       0.49900         0.637   0.644    0.0772
# 23      243656          37       0.51200         0.856   0.382    0.1060
# 24      256803          37       0.14800         0.754   0.675    0.0346
# 25      173684          35       0.01210         0.862   0.618    0.1080
# 26      182025          28       0.61700         0.823   0.889    0.0886
# 27      169637          37       0.02670         0.862   0.814    0.1630
# 28      196441          29       0.14900         0.779   0.803    0.0994
# 29      186947          32       0.23800         0.925   0.619    0.1040
# 30      156932          32       0.07610         0.709   0.799    0.1190
# 31      172355          35       0.11800         0.602   0.901    0.2960
# 32      230173          34       0.16100         0.656   0.632    0.0866
# 33      180000          24       0.54500         0.747   0.776    0.1170
# 34      223366          29       0.02390         0.850   0.741    0.2450
# 35      192001          29       0.05570         0.836   0.660    0.0975
# 36      272448          34       0.34900         0.774   0.630    0.3110
# 37      247273          29       0.38600         0.683   0.763    0.1520
# 38      160645          28       0.05990         0.825   0.670    0.1390
# 39      205754          25       0.12500         0.847   0.640    0.1090
# 40      192401          32       0.25800         0.806   0.905    0.3240
# 41      218069          30       0.08400         0.841   0.755    0.0741
# 42      224000          25       0.00547         0.807   0.733    0.1440
# 43      214000          25       0.16100         0.479   0.740    0.2130
# 44      183272          18       0.01070         0.811   0.746    0.1220
# 45      244773          26       0.09900         0.812   0.795    0.3280
# 46      157674          22       0.60700         0.824   0.581    0.0804
# 47      175099          24       0.21300         0.797   0.785    0.2570
# 48      207170          17       0.08880         0.877   0.843    0.1260
# 49      280513          27       0.02120         0.823   0.752    0.1190
#
#       tempo  valence
# 0    99.981   0.4580
# 1    78.034   0.7990
# 2    94.987   0.5600
# 3   109.979   0.5000
# 4    96.029   0.6870
# 5    97.996   0.4930
# 6   171.994   0.3420
# 7   100.043   0.0402
# 8   136.043   0.6730
# 9    88.493   0.1720
# 10  140.009   0.3170
# 11  142.118   0.6100
# 12  144.533   0.9220
# 13  180.205   0.3510
# 14  150.115   0.2280
# 15  156.096   0.4260
# 16  133.864   0.5370
# 17  160.093   0.6440
# 18  140.009   0.3170
# 19  132.004   0.3540
# 20  129.985   0.4420
# 21   75.013   0.5600
# 22  107.865   0.2070
# 23  135.070   0.2880
# 24  145.815   0.5260
# 25  160.001   0.2340
# 26  117.073   0.3500
# 27  110.035   0.8140
# 28  168.616   0.4540
# 29   95.001   0.0854
# 30  178.007   0.5670
# 31  148.073   0.7560
# 32  133.819   0.1140
# 33  172.027   0.6660
# 34  100.975   0.8090
# 35   95.041   0.7520
# 36  140.033   0.7700
# 37  136.968   0.6630
# 38  124.025   0.6460
# 39  140.078   0.6600
# 40  124.001   0.5240
# 41  127.024   0.6440
# 42  110.130   0.3600
# 43  177.023   0.4590
# 44  110.011   0.2220
# 45  119.944   0.6160
# 46  171.926   0.4630
# 47  135.064   0.7360
# 48   94.001   0.5510
# 49  130.036   0.3840
