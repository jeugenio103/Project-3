# %%
#Import Dependencies 
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import base64
from config import client_id, client_secret
import pandas as pd
from urllib.parse import urlencode
from pprint import pprint

# %%
#Sign in thru Spotidy credtentials from dashboard 
client_credentials_manager = SpotifyClientCredentials(client_id,client_secret)

#Authorize credentials with token 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Query for playlist ID 
#Playlist should be start with "This is ... " ** cap sensitive **

results= sp.search('This Is Dua Lipa', type='playlist',limit='03')

# %%
#Default spotify profile id 
#The Weeknd: d6d71314d4de46b2
#Ed Sheeran: hcdHHQdaS5mbCObLyMNbJA
#Taylor Swift: bSU-KNPcTPu1ZKlLo4R
#David Guetta: igsOuRQjQBCN6XqdN4zoUw
#Justin Bieber: 85ep_DRVT4qDcivb17mlSA
#Sam Smith: -syoKzNTQbyH-FtRHKJ3mw
#Harry Styles: E0-Lk8nyTSCX3KuPp5Y3tw
#Bad Bunny: d_A9bb8YRG-GZqr40-JFOQ
#Rihanna: W2FpEQslR_SwcGtM0xzDhQ
#Dua Lipa: AdfQ7rqeQoK84oFQOwvNRw
Spotify_profile_id = 'AdfQ7rqeQoK84oFQOwvNRw'

# %%
#Extract playlist id and name for top artist 
name = results['playlists']['items'][0]['name'].replace(" ", "_")
playlist_id = results['playlists']['items'][0]['id']
print(name)
print(playlist_id)
# Out:
# This_Is_Rihanna
# 37i9dQZF1DZ06evO3by276

# %%
#Create function to get indiidual track id 
def getTrackID(user,playlist_id):
    #Create a empty list to store ID's 
    id = []
    play_list = sp.user_playlist(user,playlist_id)

    #Loop thru ID's
    for item in play_list['tracks']['items']:
        track = item['track']
        id.append(track['id'])
    return id

# %%
#Create function to get ID features 
def getTrackFeatures(id):

    #Query spotify track and feature attribute
    info = sp.track(id)
    features = sp.audio_features(id)

    #Append info and features for specific track ID's
    name = info['name']
    album = info['album']['name']
    artist = info['album']['artists'][0]['name']
    release_date = info['album']['release_date']
    length = info['duration_ms']
    popularity = info['popularity']


    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    livenss = features[0]['liveness']
    tempo = features[0]['tempo']
    valence = features[0]['valence']

    track = [name,album,artist,release_date,length,popularity,acousticness,danceability,energy,livenss,tempo,valence]

    return track

# %%
# ('spotify_id','playlist_id')
id = getTrackID(Spotify_profile_id,playlist_id)

# %%
#Create dataframe and loop thru each track ID features to PD
playlist = []
for i in range(len(id)):
    song = getTrackFeatures(id[i])
    playlist.append(song)
    
df = pd.DataFrame(playlist,columns = ['song name','album','artist','release_date','length(ms)','popularity','acousticness','danceability','energy','liveness','tempo','valence'])
    
df.to_csv(f"./Mainstream Datasets/{name}.csv", sep = ',')

# %%
#Display dataframe 
df.head(10)
# Out:
#                                            song name  \
# 0  Lift Me Up - From Black Panther: Wakanda Forev...
# 1                                     Kiss It Better
# 2                                           Umbrella
# 3                                      We Found Love
# 4                               Don't Stop The Music
# 5                                Where Have You Been
# 6                                  Love On The Brain
# 7                                          Disturbia
# 8                               Love The Way You Lie
# 9                          This Is What You Came For
#
#                                                album         artist  \
# 0  Lift Me Up (From Black Panther: Wakanda Foreve...        Rihanna
# 1                                      ANTI (Deluxe)        Rihanna
# 2                       Good Girl Gone Bad: Reloaded        Rihanna
# 3                                     Talk That Talk        Rihanna
# 4                       Good Girl Gone Bad: Reloaded        Rihanna
# 5                                     Talk That Talk        Rihanna
# 6                                      ANTI (Deluxe)        Rihanna
# 7                       Good Girl Gone Bad: Reloaded        Rihanna
# 8                                           Recovery         Eminem
# 9                          This Is What You Came For  Calvin Harris
#
#   release_date  length(ms)  popularity  acousticness  danceability  energy  \
# 0   2022-10-28      196519          87       0.89900         0.247   0.299
# 1   2016-01-28      253080          76       0.27200         0.619   0.806
# 2   2008-06-02      275986          82       0.00864         0.583   0.829
# 3   2011-11-18      215226          77       0.02500         0.734   0.766
# 4   2008-06-02      267080          79       0.03360         0.835   0.669
# 5   2011-11-18      242680          72       0.00201         0.719   0.847
# 6   2016-01-28      224000          83       0.07170         0.509   0.637
# 7   2008-06-02      238626          81       0.08630         0.707   0.813
# 8   2010-06-18      263373          82       0.24100         0.749   0.925
# 9   2016-04-29      222160          81       0.19900         0.631   0.927
#
#    liveness    tempo  valence
# 0    0.1310  177.115    0.172
# 1    0.0671   95.000    0.877
# 2    0.0426  174.028    0.575
# 3    0.1080  127.986    0.600
# 4    0.0535  122.668    0.542
# 5    0.2210  127.963    0.444
# 6    0.0789  172.006    0.378
# 7    0.1680  124.921    0.722
# 8    0.5200   86.989    0.641
# 9    0.1480  123.962    0.465
