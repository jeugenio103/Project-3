# %%
import pandas as pd

# %%
file1 = './Data Sets/bibi.csv'
file2 = './Data Sets/chungha.csv'
file3 = './Data Sets/jackson_wang.csv'
file4= './Data Sets/joji.csv'
file5 = './Data Sets/mili.csv'
file6 = './Data Sets/niki.csv'
file7 = './Data Sets/rich_brian.csv'
file8 = './Data Sets/stephanie_poetri.csv'
file9 = './Data Sets/This_Is_Guapdad_4000.csv'
file10 = './Data Sets/This_Is_Higher_Brothers.csv'

# %%
df1 = pd.read_csv(file1, encoding="ISO-8859-1")
df2 = pd.read_csv(file2, encoding="ISO-8859-1")
df3 = pd.read_csv(file3, encoding="ISO-8859-1")
df4 = pd.read_csv(file4, encoding="ISO-8859-1")
df5 = pd.read_csv(file5, encoding="ISO-8859-1")
df6 = pd.read_csv(file6, encoding="ISO-8859-1")
df7 = pd.read_csv(file7, encoding="ISO-8859-1")
df8 = pd.read_csv(file8, encoding="ISO-8859-1")
df9 = pd.read_csv(file9, encoding="ISO-8859-1")
df10 = pd.read_csv(file10, encoding="ISO-8859-1")

# %%
Rising88DF = pd.concat([df1, df2, df3,df4,df5,df5,df6,df7,df8,df9,df10])

# %%
Rising88DF = Rising88DF.rename(
    columns={"Unnamed: 0": "ID"})

# %%
Rising88DF.set_index(['ID'], inplace=True)
# Out:
#                           song name  \
# ID
# 0                       The Weekend
# 1                 LAW (Prod. Czaer)
# 2                        Best Lover
# 3                       Animal Farm
# 4                            KAZINO
# ..                              ...
# 45                         Wudidong
# 46                        5:30 A.M.
# 47                     Room Service
# 48  King of the Jungle (feat. Melo)
# 49                             Yahh
#
#                                                 album           artist  \
# ID
# 0                                         The Weekend         88rising
# 1   Street Man Fighter Original Vol.3 (Mission by ...  Various Artists
# 2                          Head In The Clouds Forever         88rising
# 3                                         Animal Farm             BIBI
# 4                                              KAZINO             BIBI
# ..                                                ...              ...
# 45                                          Black Cab  Higher Brothers
# 46                                        Type-3 - EP  Higher Brothers
# 47                           Journey to the West - EP  Higher Brothers
# 48                                         PSYLIFE.25            Psy.P
# 49                                          Black Cab  Higher Brothers
#
#    release_date  length(ms)  popularity  acousticness  danceability  energy  \
# ID
# 0    2021-10-14      167661          69       0.06200         0.784   0.521
# 1    2022-09-06      189373          71       0.00857         0.756   0.900
# 2    2022-04-16      152910          66       0.26800         0.740   0.663
# 3    2022-09-27      203945          69       0.01780         0.617   0.570
# 4    2020-04-29      185946          65       0.13900         0.625   0.686
# ..          ...         ...         ...           ...           ...     ...
# 45   2017-05-31      244773          26       0.09900         0.812   0.795
# 46   2018-02-27      157674          22       0.60700         0.824   0.581
# 47   2018-01-17      175099          24       0.21300         0.797   0.785
# 48   2020-05-26      207170          17       0.08880         0.877   0.843
# 49   2017-05-31      280513          27       0.02120         0.823   0.752
#
#     liveness    tempo  valence
# ID
# 0     0.0995  101.491    0.817
# 1     0.2370  128.054    0.550
# 2     0.1210   82.004    0.519
# 3     0.5500  107.971    0.375
# 4     0.1100  133.041    0.263
# ..       ...      ...      ...
# 45    0.3280  119.944    0.616
# 46    0.0804  171.926    0.463
# 47    0.2570  135.064    0.736
# 48    0.1260   94.001    0.551
# 49    0.1190  130.036    0.384
#
# [521 rows x 12 columns]

# %%
Rising88DF.drop_duplicates()
# Out:
#     ID                        song name  \
# 0    0                      The Weekend
# 1    1                LAW (Prod. Czaer)
# 2    2                       Best Lover
# 3    3                      Animal Farm
# 4    4                           KAZINO
# ..  ..                              ...
# 45  45                         Wudidong
# 46  46                        5:30 A.M.
# 47  47                     Room Service
# 48  48  King of the Jungle (feat. Melo)
# 49  49                             Yahh
#
#                                                 album           artist  \
# 0                                         The Weekend         88rising
# 1   Street Man Fighter Original Vol.3 (Mission by ...  Various Artists
# 2                          Head In The Clouds Forever         88rising
# 3                                         Animal Farm             BIBI
# 4                                              KAZINO             BIBI
# ..                                                ...              ...
# 45                                          Black Cab  Higher Brothers
# 46                                        Type-3 - EP  Higher Brothers
# 47                           Journey to the West - EP  Higher Brothers
# 48                                         PSYLIFE.25            Psy.P
# 49                                          Black Cab  Higher Brothers
#
#    release_date  length(ms)  popularity  acousticness  danceability  energy  \
# 0    2021-10-14      167661          69       0.06200         0.784   0.521
# 1    2022-09-06      189373          71       0.00857         0.756   0.900
# 2    2022-04-16      152910          66       0.26800         0.740   0.663
# 3    2022-09-27      203945          69       0.01780         0.617   0.570
# 4    2020-04-29      185946          65       0.13900         0.625   0.686
# ..          ...         ...         ...           ...           ...     ...
# 45   2017-05-31      244773          26       0.09900         0.812   0.795
# 46   2018-02-27      157674          22       0.60700         0.824   0.581
# 47   2018-01-17      175099          24       0.21300         0.797   0.785
# 48   2020-05-26      207170          17       0.08880         0.877   0.843
# 49   2017-05-31      280513          27       0.02120         0.823   0.752
#
#     liveness    tempo  valence
# 0     0.0995  101.491    0.817
# 1     0.2370  128.054    0.550
# 2     0.1210   82.004    0.519
# 3     0.5500  107.971    0.375
# 4     0.1100  133.041    0.263
# ..       ...      ...      ...
# 45    0.3280  119.944    0.616
# 46    0.0804  171.926    0.463
# 47    0.2570  135.064    0.736
# 48    0.1260   94.001    0.551
# 49    0.1190  130.036    0.384
#
# [471 rows x 13 columns]

# %%
Rising88DF.to_csv('./Data Sets/final88data.csv', sep = ',')
