# %%
#Install module 
pip install spotipy

# %%
#Import Dependencies 
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import base64
from config import client_id, client_secret
import pandas as pd
from urllib.parse import urlencode
from pprint import pprint

# %%
#Sign in thru Spotidy credtentials from dashboard 
client_credentials_manager = SpotifyClientCredentials(client_id,client_secret)

#Authorize credentials with token 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Query for playlist ID 
#Playlist should be start with "This is ... " ** cap sensitive **

results= sp.search('This Is Guapdad 4000', type='playlist',limit='03')
pprint(results)
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=This+Is+Guapdad+4000&type=playlist&offset=0&limit=3',
#                'items': [{'collaborative': False,
#                           'description': 'This is Guapdad 4000. The essential '
#                                          'tracks, all in one playlist.',
#                           'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DZ06evO0p8kTb'},
#                           'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO0p8kTb',
#                           'id': '37i9dQZF1DZ06evO0p8kTb',
#                           'images': [{'height': None,
#                                       'url': 'https://thisis-images.scdn.co/37i9dQZF1DZ06evO0p8kTb-large.jpg',
#                                       'width': None}],
#                           'name': 'This Is Guapdad 4000',
#                           'owner': {'display_name': 'Spotify',
#                                     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#                                     'href': 'https://api.spotify.com/v1/users/spotify',
#                                     'id': 'spotify',
#                                     'type': 'user',
#                                     'uri': 'spotify:user:spotify'},
#                           'primary_color': None,
#                           'public': None,
#                           'snapshot_id': 'Mjc3OTE0NjUsMDAwMDAwMDBkMTQ1NTZkNTg2MTlmNmY1OWJiOGY4OTdhODBhMDk2YQ==',
#                           'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO0p8kTb/tracks',
#                                      'total': 50},
#                           'type': 'playlist',
#                           'uri': 'spotify:playlist:37i9dQZF1DZ06evO0p8kTb'},
#                          {'collaborative': False,
#                           'description': 'This is Guadalupe Pineda. The '
#                                          'essential tracks, all in one '
#                                          'playlist.',
#                           'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DZ06evO3RCNxo'},
#                           'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO3RCNxo',
#                           'id': '37i9dQZF1DZ06evO3RCNxo',
#                           'images': [{'height': None,
#                                       'url': 'https://thisis-images.scdn.co/37i9dQZF1DZ06evO3RCNxo-large.jpg',
#                                       'width': None}],
#                           'name': 'This Is Guadalupe Pineda',
#                           'owner': {'display_name': 'Spotify',
#                                     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#                                     'href': 'https://api.spotify.com/v1/users/spotify',
#                                     'id': 'spotify',
#                                     'type': 'user',
#                                     'uri': 'spotify:user:spotify'},
#                           'primary_color': None,
#                           'public': None,
#                           'snapshot_id': 'Mjc3OTE0NjUsMDAwMDAwMDA3NTc0Y2E4ZDc2YTEwNDVmNjQ1ODIyZmRiNWQzZTViZg==',
#                           'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO3RCNxo/tracks',
#                                      'total': 50},
#                           'type': 'playlist',
#                           'uri': 'spotify:playlist:37i9dQZF1DZ06evO3RCNxo'},
#                          {'collaborative': False,
#                           'description': 'This is Guaynaa. The essential '
#                                          'tracks, all in one playlist.',
#                           'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DZ06evO0i3bBb'},
#                           'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO0i3bBb',
#                           'id': '37i9dQZF1DZ06evO0i3bBb',
#                           'images': [{'height': None,
#                                       'url': 'https://thisis-images.scdn.co/37i9dQZF1DZ06evO0i3bBb-large.jpg',
#                                       'width': None}],
#                           'name': 'This Is Guaynaa',
#                           'owner': {'display_name': 'Spotify',
#                                     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#                                     'href': 'https://api.spotify.com/v1/users/spotify',
#                                     'id': 'spotify',
#                                     'type': 'user',
#                                     'uri': 'spotify:user:spotify'},
#                           'primary_color': None,
#                           'public': None,
#                           'snapshot_id': 'Mjc3OTE0NjUsMDAwMDAwMDA4NTg2NDExN2NjODk4MGE5NTY5OTViM2Q5ZTMwNTlmNQ==',
#                           'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO0i3bBb/tracks',
#                                      'total': 50},
#                           'type': 'playlist',
#                           'uri': 'spotify:playlist:37i9dQZF1DZ06evO0i3bBb'}],
#                'limit': 3,
#                'next': 'https://api.spotify.com/v1/search?query=This+Is+Guapdad+4000&type=playlist&offset=3&limit=3',
#                'offset': 0,
#                'previous': None,
#                'total': 20}}

# %%
#Default spotify profile id 
Spotify_profile_id = 'cef03df234f441af'

# %%
#Extract playlist id and name for top artist 
name = results['playlists']['items'][0]['name'].replace(" ", "_")
playlist_id = results['playlists']['items'][0]['id']
print(name)
print(playlist_id)
# Out:
# This_Is_Guapdad_4000
# 37i9dQZF1DZ06evO0p8kTb

# %%
#Create function to get indiidual track id 
def getTrackID(user,playlist_id):
    #Create a empty list to store ID's 
    id = []
    play_list = sp.user_playlist(user,playlist_id)

    #Loop thru ID's
    for item in play_list['tracks']['items']:
        track = item['track']
        id.append(track['id'])
    return id

# %%
#Create function to get ID features 
def getTrackFeatures(id):

    #Query spotify track and feature attribute
    info = sp.track(id)
    features = sp.audio_features(id)

    #Append info and features for specific track ID's
    name = info['name']
    album = info['album']['name']
    artist = info['album']['artists'][0]['name']
    release_date = info['album']['release_date']
    length = info['duration_ms']
    popularity = info['popularity']


    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    livenss = features[0]['liveness']
    tempo = features[0]['tempo']
    valence = features[0]['valence']

    track = [name,album,artist,release_date,length,popularity,acousticness,danceability,energy,livenss,tempo,valence]

    return track

# %%
# ('spotify_id','playlist_id')
id = getTrackID(Spotify_profile_id,playlist_id)

# %%
#Create dataframe and loop thru each track ID features to PD
playlist = []
for i in range(len(id)):
    song = getTrackFeatures(id[i])
    playlist.append(song)
    
df = pd.DataFrame(playlist,columns = ['song name','album','artist','release_date','length(ms)','popularity','acousticness','danceability','energy','liveness','tempo','valence'])
    
df.to_csv(f"./Data Sets/{name}.csv", sep = ',')

# %%
#Display dataframe 
df.head(10)
# Out:
#                                            song name  \
# 0  Costa Rica (with Bas & JID feat. Guapdad 4000,...
# 1                           Dragonball Durag - Remix
# 2                                           Fearless
# 3                                               BALI
# 4  Wells Fargo (with JID & EARTHGANG feat. Buddy ...
# 5                               Poppin Pills - Remix
# 6                Pose (feat. Wiz Khalifa & Curren$y)
# 7                                            TOO BAD
# 8  Don't Hit Me Right Now (with Bas & Cozz feat. ...
# 9                                      Black Iverson
#
#                                  album        artist release_date  length(ms)  \
# 0          Revenge Of The Dreamers III    Dreamville   2019-07-05      217866
# 1             Dragonball Durag (Remix)    Thundercat   2020-08-25      221098
# 2                             Fearless  Guapdad 4000   2022-01-26      140000
# 3                                 BALI    Rich Brian   2020-04-10      199384
# 4          Revenge Of The Dreamers III    Dreamville   2019-07-05      123413
# 5                 Poppin Pills (Remix)          Jace   2022-05-20      112300
# 6  Pose (feat. Wiz Khalifa & Curren$y)  Guapdad 4000   2022-06-10      204528
# 7                              TOO BAD       Kembe X   2020-12-11      189380
# 8          Revenge Of The Dreamers III    Dreamville   2019-07-05      174360
# 9                        Black Iverson  Guapdad 4000   2022-04-29      185924
#
#    popularity  acousticness  danceability  energy  liveness    tempo  valence
# 0          67      0.517000         0.642   0.647    0.0649  120.749    0.664
# 1          54      0.614000         0.626   0.597    0.1220   80.985    0.578
# 2          52      0.000446         0.696   0.978    0.1050  107.971    0.762
# 3          51      0.010700         0.855   0.645    0.2260  129.999    0.654
# 4          56      0.070600         0.800   0.826    0.1810  148.021    0.241
# 5          34      0.303000         0.640   0.704    0.2170  160.048    0.563
# 6          46      0.055000         0.760   0.612    0.0375  187.934    0.662
# 7          44      0.118000         0.814   0.599    0.1260   77.540    0.686
# 8          48      0.561000         0.779   0.597    0.1310  124.056    0.432
# 9          45      0.024800         0.742   0.523    0.0905  155.547    0.283
